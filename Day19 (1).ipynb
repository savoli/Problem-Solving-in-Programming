# %% [markdown]
# # Problem Solving and Programming
# Day No: 18
#
# Date :17/05/2019
#
# # Problem 1
# Define a function to read from a csv file using the pandas library
# Display the csv file data as output

# %%
import pandas as pd
def reaCSV(filename):
    df=pd.read_csv(filename)
    return df

df=readCSV('csv.txt')
df.columns[0]
           
df.tail(5)
df.head(1)
df.iat[2,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-aa93dbfbbbcc> in <module>
#       4     return df
#       5
# ----> 6 df=readCSV('csv.txt')
#       7 df.columns[0]
#       8
#
# NameError: name 'readCSV' is not defined

# %%
def addRCSV(filename,rdata):
    df=readCSV(filename)
    df.loc[len(df)]=rdata
    df.to_CSV(filename)
    return df


rdata=['010101','sname',123,456,345,564,678,789,657,689,987]
addRCSV('CSV.txt',rdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e240b14794de> in <module>
#       7
#       8 rdata=['010101','sname',123,456,345,564,678,789,657,689,987]
# ----> 9 addRCSV('CSV.txt',rdata)
#
# <ipython-input-6-e240b14794de> in addRCSV(filename, rdata)
#       1 def addRCSV(filename,rdata):
# ----> 2     df=readCSV(filename)
#       3     df.loc[len(df)]=rdata
#       4     df.to_CSV(filename)
#       5     return df
#
# NameError: name 'readCSV' is not defined

# %%
import pandas as pd
df=pd.read_csv("D:/MOCK_DATA.csv")
df
# Out:
#    id first_name last_name                          email  gender  \
# 0   1   Pearline   Forsyth           pforsyth0@utexas.edu  Female
# 1   2         Jo    Fogden    jfogden1@barnesandnoble.com    Male
# 2   3      Nissa  Queripel              nqueripel2@ca.gov  Female
# 3   4       Gill    Ivanov  givanov3@pagesperso-orange.fr    Male
# 4   5      Coral   Danaher        cdanaher4@shinystat.com  Female
# 5   6     Julina   Gabriel      jgabriel5@dailymotion.com  Female
# 6   7      Ignaz    Catton        icatton6@guardian.co.uk    Male
# 7   8     Osborn    Gridon              ogridon7@ehow.com    Male
# 8   9     Janeva      Jupe               jjupe8@bbc.co.uk  Female
# 9  10       Erna  Margeram           emargeram9@hexun.com  Female
#
#         ip_address
# 0  145.208.212.219
# 1   65.232.104.250
# 2    165.58.105.44
# 3     60.234.58.11
# 4      56.234.6.80
# 5     1.206.91.148
# 6    244.15.31.243
# 7   16.179.252.176
# 8    113.47.58.113
# 9   206.136.149.92
