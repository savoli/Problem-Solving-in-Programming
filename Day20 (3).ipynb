# %% [markdown]
# # Problem Solving and Programming
# Day No: 20
#
# Date :18/05/2019

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab 
plt.plot([1,2,3,4],[3,4,5,6])
plt.xlabel('time')
plt.ylabel('distance')
#plt.plot(t,v)
plt.grid(True)
plt.show()

# %%
#import matplotlib.pyplot as plt
#import matplotlib.mlab as mlab 
import numpy as np
t=np.arange(0.0,2.0,0.1)
v=1+np.sin((2*np.pi*t))
#plt.plot([1,2,3,4],[3,4,5,6])
plt.xlabel('time', color="red")
plt.ylabel('distance', color="yellow")
plt.plot(t,v,color="red",alpha=.5)
plt.grid(True)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('D:/MOCK_DATA.csv')
df.values[4]
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
objects = ('TDP', 'YSRCP', 'JSP', 'CPI/CPM', 'CONG', 'OTHERS')
y_pos = np.arange(len(objects))
performance = [77,59,16,10,3,12]
plt.bar(y_pos, performance, align='center', alpha=1, color=("yellow","green","orange","red","blue","pink"))
plt.xticks(y_pos, objects)
plt.ylabel('SEATS')
plt.title('PARTIES')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlt
labels = "TDP","YSRCP","JSP+","OTHERS"
sizes = [83,63,18,7]
colors=["yellow","green","red","blue"]
explode = (0,0.0,0.2,0.0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.2f%%', shadow=True)
plt.axis('equal')
plt.show()
